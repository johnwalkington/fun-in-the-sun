# %%
import pandas as pd
import numpy as np
import csv
import os



# Read data for ingredient
df_ingred=pd.read_csv(os.path.join("Data","Fitered_ingredients.csv"))
df_ingred=df_ingred.reset_index()[['Catalog No.','Filtered_Ingredients']]
df_ingred=df_ingred.rename(columns={'Catalog No.':'Product_ID','Filtered_Ingredients':'Filtered_Ingredients'})
df_ingred


# Read data for skin type
df_type=pd.read_csv(os.path.join("Data","Skin_wreviews_cleaned.csv"))
df_type=df_type.reset_index()[['Product_ID','Skin_Type']]
df_type



# Doing inner join
inner_join_df= pd.merge(df_ingred, df_type, on='Product_ID', how='inner')
inner_join_df 


# Combination type
Comb_df=inner_join_df[inner_join_df['Skin_Type'] == 'Combination'].reset_index()
Comb_df = Comb_df.iloc[:, 1:]

#1794 rows (53.5%)


# Dry type
Dry_df=inner_join_df[inner_join_df['Skin_Type'] == 'Dry'].reset_index()
Dry_df = Dry_df.iloc[:, 1:]

#697 rows (20.4%)


# Oily type
Oily_df=inner_join_df[inner_join_df['Skin_Type'] == 'Oily'].reset_index()
Oily_df = Oily_df.iloc[:, 1:]

#486 rows (14.2%)


# Normal type
Norm_df=inner_join_df[inner_join_df['Skin_Type'] == 'Normal'].reset_index()
Norm_df = Norm_df.iloc[:, 1:]

#394 rows (11.9%)

# %%
#Finding top 10 ingredients for Combination type skin

# %%
Comb_df = Comb_df.drop_duplicates('Product_ID')

# %%
di= {}

# %%
for ing_list in Comb_df.Filtered_Ingredients: 
    for ing in (ing_list.strip('[').strip(']').strip('\"').strip('\'').split(',')):
        ing = (ing.strip('\'').strip().strip('\'').strip())
        ing = str(ing)

        if ing not in di.keys():
            di[ing] = 1
        else: 
            di[ing] += 1

# %%
df_comb = pd.DataFrame.from_dict(di, orient = 'index', columns=['Count'])

# %%
df_comb = df_comb.reset_index()
df_comb.columns = ['Ingredient', 'Count']
df_comb = df_comb.sort_values("Count", ascending = False).head(15)

# %%
df_comb=df_comb.reset_index().iloc[:, 1:]
df_comb
# Out:
#           Ingredient  Count
# 0         OCTINOXATE     90
# 1   TITANIUM DIOXIDE     84
# 2      UVINUL A PLUS     69
# 3         ZINC OXIDE     65
# 4         TINOSORB S     62
# 5         OCTISALATE     45
# 6       UVINUL T 150     32
# 7        OCTOCRYLENE     24
# 8         HOMOSALATE     22
# 9         AVOBENZONE     20
# 10        PARSOL SLX     17
# 11        TINOSORB M     13
# 12         AMILOXATE     10
# 13        ENSULIZOLE      9
# 14      ISCOTRIZINOL      9

# %%
#Finding top 10 ingredients for Dry type skin

# %%
Dry_df = Dry_df.drop_duplicates('Product_ID')

# %%
di= {}

# %%
for ing_list in Dry_df.Filtered_Ingredients: 
    for ing in (ing_list.strip('[').strip(']').strip('\"').strip('\'').split(',')):
        ing = (ing.strip('\'').strip().strip('\'').strip())
        ing = str(ing)

        if ing not in di.keys():
            di[ing] = 1
        else: 
            di[ing] += 1

# %%
df_dry = pd.DataFrame.from_dict(di, orient = 'index', columns=['Count'])

# %%
df_dry = df_dry.reset_index()
df_dry.columns = ['Ingredient', 'Count']
df_dry = df_dry.sort_values("Count", ascending = False).head(15)

# %%
df_dry=df_dry.reset_index().iloc[:, 1:]
df_dry
# Out:
#           Ingredient  Count
# 0         OCTINOXATE     63
# 1   TITANIUM DIOXIDE     48
# 2      UVINUL A PLUS     46
# 3         TINOSORB S     42
# 4         ZINC OXIDE     32
# 5         OCTISALATE     32
# 6        OCTOCRYLENE     20
# 7         AVOBENZONE     19
# 8       UVINUL T 150     18
# 9         HOMOSALATE     14
# 10        PARSOL SLX      9
# 11         AMILOXATE      9
# 12        TINOSORB M      9
# 13      ISCOTRIZINOL      6
# 14        ENSULIZOLE      5

# %%
#Finding top 10 ingredients for Oily type skin

# %%
Oily_df = Oily_df.drop_duplicates('Product_ID')
di= {}
for ing_list in Oily_df.Filtered_Ingredients: 
    for ing in (ing_list.strip('[').strip(']').strip('\"').strip('\'').split(',')):
        ing = (ing.strip('\'').strip().strip('\'').strip())
        ing = str(ing)

        if ing not in di.keys():
            di[ing] = 1
        else: 
            di[ing] += 1
df_oily = pd.DataFrame.from_dict(di, orient = 'index', columns=['Count'])
df_oily = df_oily.reset_index()
df_oily.columns = ['Ingredient', 'Count']
df_oily = df_oily.sort_values("Count", ascending = False).head(15)
df_oily=df_oily.reset_index().iloc[:, 1:]
df_oily
# Out:
#           Ingredient  Count
# 0         OCTINOXATE     51
# 1   TITANIUM DIOXIDE     45
# 2      UVINUL A PLUS     43
# 3         ZINC OXIDE     37
# 4         TINOSORB S     34
# 5         OCTISALATE     30
# 6       UVINUL T 150     18
# 7        OCTOCRYLENE     16
# 8         AVOBENZONE     15
# 9         HOMOSALATE     14
# 10        TINOSORB M     11
# 11        PARSOL SLX      9
# 12      ISCOTRIZINOL      6
# 13        ENSULIZOLE      3
# 14         AMILOXATE      3

# %%
#Finding top 10 ingredients for Normal type skin

# %%
Norm_df = Norm_df.drop_duplicates('Product_ID')
di= {}
for ing_list in Norm_df.Filtered_Ingredients: 
    for ing in (ing_list.strip('[').strip(']').strip('\"').strip('\'').split(',')):
        ing = (ing.strip('\'').strip().strip('\'').strip())
        ing = str(ing)

        if ing not in di.keys():
            di[ing] = 1
        else: 
            di[ing] += 1
df_norm = pd.DataFrame.from_dict(di, orient = 'index', columns=['Count'])
df_norm = df_norm.reset_index()
df_norm.columns = ['Ingredient', 'Count']
df_norm = df_norm.sort_values("Count", ascending = False).head(15)
df_norm=df_norm.reset_index().iloc[:, 1:]
df_norm
# Out:
#           Ingredient  Count
# 0         OCTINOXATE     53
# 1      UVINUL A PLUS     43
# 2   TITANIUM DIOXIDE     41
# 3         TINOSORB S     38
# 4         OCTISALATE     31
# 5         ZINC OXIDE     31
# 6       UVINUL T 150     18
# 7         AVOBENZONE     18
# 8        OCTOCRYLENE     17
# 9         HOMOSALATE     17
# 10        PARSOL SLX     12
# 11        TINOSORB M      9
# 12         AMILOXATE      5
# 13        ENSULIZOLE      4
# 14      ISCOTRIZINOL      4

# %%
#compare ingredients for all four skin types

# %%
df_list = [df_comb, df_dry, df_oily, df_norm]
df_all = pd.concat(df_list, axis=1,ignore_index=True)
df_all.columns=['Combination','Count','Dry','Count','Oily','Count','Normal','Count']
df_all
# Out:
#          Combination  Count               Dry  Count              Oily  Count  \
# 0         OCTINOXATE     90        OCTINOXATE     63        OCTINOXATE     51
# 1   TITANIUM DIOXIDE     84  TITANIUM DIOXIDE     48  TITANIUM DIOXIDE     45
# 2      UVINUL A PLUS     69     UVINUL A PLUS     46     UVINUL A PLUS     43
# 3         ZINC OXIDE     65        TINOSORB S     42        ZINC OXIDE     37
# 4         TINOSORB S     62        ZINC OXIDE     32        TINOSORB S     34
# 5         OCTISALATE     45        OCTISALATE     32        OCTISALATE     30
# 6       UVINUL T 150     32       OCTOCRYLENE     20      UVINUL T 150     18
# 7        OCTOCRYLENE     24        AVOBENZONE     19       OCTOCRYLENE     16
# 8         HOMOSALATE     22      UVINUL T 150     18        AVOBENZONE     15
# 9         AVOBENZONE     20        HOMOSALATE     14        HOMOSALATE     14
# 10        PARSOL SLX     17        PARSOL SLX      9        TINOSORB M     11
# 11        TINOSORB M     13         AMILOXATE      9        PARSOL SLX      9
# 12         AMILOXATE     10        TINOSORB M      9      ISCOTRIZINOL      6
# 13        ENSULIZOLE      9      ISCOTRIZINOL      6        ENSULIZOLE      3
# 14      ISCOTRIZINOL      9        ENSULIZOLE      5         AMILOXATE      3
#
#               Normal  Count
# 0         OCTINOXATE     53
# 1      UVINUL A PLUS     43
# 2   TITANIUM DIOXIDE     41
# 3         TINOSORB S     38
# 4         OCTISALATE     31
# 5         ZINC OXIDE     31
# 6       UVINUL T 150     18
# 7         AVOBENZONE     18
# 8        OCTOCRYLENE     17
# 9         HOMOSALATE     17
# 10        PARSOL SLX     12
# 11        TINOSORB M      9
# 12         AMILOXATE      5
# 13        ENSULIZOLE      4
# 14      ISCOTRIZINOL      4
