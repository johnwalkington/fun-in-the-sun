# %%
comment = 'La este es un (la) ejemplo_la_la de un_la (la) comentario español. La la '

# %%
from nltk.tokenize import word_tokenize

# %%
# new_comment = word_tokenize(comment.lower())
new_comment = comment.lower().split()

# %%
' '.join([c for c in new_comment if c != 'la'])
# Can also scrub punctuation with re.sub
# Out:
# 'este es un (la) ejemplo_la_la de un_la (la) comentario español.'
